# %%
from collections import deque

# Graph Representation: Adjacency List
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

def bfs(graph, start, goal):
    try:
        # Check if the start or goal is not in the graph
        if start not in graph or goal not in graph:
            raise ValueError(f"Start node '{start}' or goal node '{goal}' is not in the graph.")
        
        visited = set()  # To track visited nodes
        queue = deque([start])  # Queue for BFS
        result = []  # To store the path from start to goal
        
        while queue:
            node = queue.popleft()

            if node == goal:
                result.append(node)
                return result  # Return the path as soon as we find the goal

            if node not in visited:
                visited.add(node)
                result.append(node)  # Add the current node to the path
                queue.extend(graph[node])  # Add adjacent nodes to the queue
        
        return f"No path found from {start} to {goal}."  # If goal is not found

    except ValueError as ve:
        return str(ve)  # Return the error message if nodes are not in the graph

    except Exception as e:
        return f"An error occurred: {str(e)}"  # Catch any other unexpected errors

def main():
    start_node = 'A'
    goal_node = 'F'

    print(f"Running BFS from {start_node} to {goal_node}...")
    result = bfs(graph, start_node, goal_node)

    if isinstance(result, list):
        print(f"BFS: Path from {start_node} to {goal_node} found!")
        print(f"Path: {' -> '.join(result)}")
    else:
        print(result)  # Print the error message if no path is found or error occurs

# Entry point of the script
if __name__ == "__main__":
    main()
# Out:
# Running BFS from A to F...
# BFS: Path from A to F found!
# Path: A -> B -> C -> D -> E -> F

# %%
from collections import deque

# Graph Representation: Adjacency List
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

def bfs(graph,start,goal):
    try:
        if start not in graph or goal not in graph:
            raise ValueError (f" '{start}' and '{goal}' is not found in the graph")

        visited=set()
        queue=deque([start])
        result=[]

        while queue:
            node=queue.popleft()

            if node == goal :
                result.append(node)
                return result

            if node not in visited:
                visited.add(node)
                result.append(node)
                queue.extend(graph[node])

        return f" path not found "

    except ValuError as ve:
        return str(ve)

    except Exception as e:
        return f" error occured: {str(e)}"

def main():
    start='A'
    goal='F'

    print(f" Searching for path")
    result=bfs(graph,start,goal)

    if isinstance(result,list):
        print(f"Path is found")
        print(f" {'->'.join(result)}")

    else:
        print(result)

if __name__ == "__main__":
    main()
# Out:
#  Searching for path
# Path is found
#  A->B->C->D->E->F

# %%
from collections import deque
graph ={
    'A':['B','C'],
    'B':['D','E'],
    'C':['F'],
    'D':[],
    'E':[],
    'F':[]
}

def bfs(graph,start,goal):
    try:
        if start not in graph or goal not in graph:
            raise ValueError(f" {start} and {goal} is not found")

        visited=set()
        queue=deque([start])
        result=[]

        while queue:
            node=queue.popleft()

            if node == goal :
                result.append(node)
                return result

            if node not in visited:
                visited.add(node)
                result.append(node)
                queue.extend(graph[node])

        return f" path noy found "

    except ValueError as ve:
        return f"{str(ve)}"

    except Exception as e:
        return f"{str(e)}"

def main():
    start='A'
    goal='F'

    path=bfs(graph,start,goal)

    if isinstance(path,list):
        print(f"{path}")

    else:
        print(path)

if __name__ =="__main__":
    main()
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
from collections import deque

# Graph Representation: Adjacency List
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

def bfs(graph,start,node):
    visited=set()
    queue=deque([start])
    result=[]

    while queue:
        node=queue.popleft()
        if node == goal:
            result.append(node)
            return result

        if node not in visited:
            visited.add(node)
            result.append(node)
            queue.extend(graph[node])
    return result


start='A'
goal='F'

result=bfs(graph,start,goal)

print(f"{result}")
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']
